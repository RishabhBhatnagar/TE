# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('iris1.csv')

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(data['petal_length'],data['petal_width'])

# %%
plt.show()

# %%
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('iris1.csv')

# %%
x=sns.pairplot(data, hue='species', size=2.5)

# %%
plt.show(x)

# %% [markdown]
# # Data Correlation

# %% [markdown]
# // When the number of attributes is more then you can find this correlation matrix and highly correlated can be used for linear regression

# %%
data.corr(method='spearman')
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.157698      0.881955     0.836057
# sepal_width      -0.157698     1.000000     -0.301088    -0.276013
# petal_length      0.881955    -0.301088      1.000000     0.935795
# petal_width       0.836057    -0.276013      0.935795     1.000000
